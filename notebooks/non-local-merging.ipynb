# %%
import sys
import logging
import os


sys.path.append("..")
# %load_ext autoreload
# %autoreload 2


logger = logging.getLogger()
logger.setLevel(logging.INFO)

os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION']='.95'

# %%
import pickle
from tqdm import tqdm

import jax
from jax import random
import jax.numpy as jnp
import numpy as np

from configs import finetune
from data import input_pipeline
import models
import utils
from utils import restore_checkpoint
from permutations import *
from constants import *
from pruning import apply_mask
from configs.eval_merge import get_config
import merging
# Out:
# 2024-10-11 14:28:14.205614: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-11 14:28:14.218716: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-11 14:28:14.218736: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-11 14:28:14.738488: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-10-11 14:28:15.554539: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/ekansh/anaconda3/envs/vision-models/lib/python3.9/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
from trainer import update_batch_stats
import functools
from flax.training import common_utils
from trainer import compute_metrics

def get_metrics(metrics):
    return common_utils.stack_forest(metrics)


@functools.partial(jax.jit, static_argnums=(0,))
def eval_step(apply_fn, params, batch):
    logits = apply_fn(params, batch['image'], deterministic=True)
    metrics = compute_metrics(logits, batch['label'])
    return metrics


def compute_loss_and_accuracy(apply_fn, params, dataset, nbatches=None):
    eval_iter = input_pipeline.prefetch(dataset, 10, None)
    eval_metrics = []
    ix = 0
    for eval_batch in eval_iter:
        metrics = eval_step(apply_fn, params, eval_batch)
        eval_metrics.append(metrics)
        ix+=1
        if nbatches is not None:
            if ix >= nbatches:
                break

    eval_metrics = get_metrics(eval_metrics)
    summary = {
            f'eval_{k}': v
            for k, v in jax.tree_util.tree_map(
            lambda x: x.mean(), eval_metrics
            ).items()
    }

    return summary['eval_loss'], summary['eval_accuracy']



norm_acc = lambda acc, expert_acc: acc / expert_acc

# %%
model_name = 'VGG16'
ntasks = 8
crop = 96
tasks = TASKS_A[:ntasks//2] + TASKS_B[:ntasks//2]
datasets = ".".join(tasks)
config = get_config(f"{model_name},{datasets},average-merging")
config.width_multiplier = 2

config.task_a_init = VGG16X2_NONLOCAL_TASK_A_INIT
config.task_b_init = VGG16X2_NONLOCAL_TASK_B_INIT


for dataset in TASKS_A[:ntasks//2]:
  config[dataset].pp.crop = crop
  config[dataset].model_dir = VGG16X2_A[dataset]

for dataset in TASKS_B[:ntasks//2]:
  config[dataset].pp.crop = crop
  config[dataset].model_dir = VGG16X2_B[dataset]

# %%
datasets = config.datasets
dataset_info_ls = [input_pipeline.get_dataset_info(dataset, config[dataset].pp['train']) for dataset in config.datasets]
num_classes = [dataset_info['num_classes'] for dataset_info in dataset_info_ls] 
num_train_examples = [dataset_info['num_examples'] for dataset_info in dataset_info_ls]

ds_train_ls, ds_test_ls = input_pipeline.get_datasets_for_mtl(config, datasets, batch_size=128)

model_ls = []
model_tracker_ls = []
model_repaired_ls = []
param_dirs = []

for i, nclass in enumerate(num_classes): 
  model_ls += [models.create_model(model_cls=getattr(models, config.model), num_classes=nclass, half_precision=False, projection_dim=512, width_multiplier=config.width_multiplier)]
  model_tracker_ls += [models.create_model(model_cls=getattr(models, config.model), num_classes=nclass, half_precision=False, projection_dim=512, width_multiplier=config.width_multiplier, tracker=True)]
  model_repaired_ls += [models.create_model(model_cls=getattr(models, config.model), num_classes=nclass, half_precision=False, projection_dim=512, width_multiplier=config.width_multiplier, repaired=True)]
# Out:
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2
# INFO:absl:For 'cifar10/3.0.2': fields info.[splits, supervised_keys] differ on disk and in the code. Keeping the one from code.
# INFO:absl:No config specified, defaulting to config: eurosat/rgb
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0
# INFO:absl:For 'svhn_cropped/3.0.0': fields info.[description, citation, module_name] differ on disk and in the code. Keeping the one from code.
# INFO:absl:Reading dataset from tfds "colorectal_histology"
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0
# INFO:absl:Reusing dataset colorectal_histology (/mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0)
# INFO:absl:Constructing tf.data.Dataset colorectal_histology for split train[:90%], from /mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0
# INFO:absl:Reusing dataset colorectal_histology (/mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0)
# INFO:absl:Constructing tf.data.Dataset colorectal_histology for split train[90%:], from /mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0
# INFO:absl:Reading dataset from tfds "cifar10"
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2
# INFO:absl:For 'cifar10/3.0.2': fields info.[splits, supervised_keys] differ on disk and in the code. Keeping the one from code.
# INFO:absl:Reusing dataset cifar10 (/mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2)
# INFO:absl:Constructing tf.data.Dataset cifar10 for split train, from /mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2
# INFO:absl:For 'cifar10/3.0.2': fields info.[splits, supervised_keys] differ on disk and in the code. Keeping the one from code.
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2
# INFO:absl:For 'cifar10/3.0.2': fields info.[splits, supervised_keys] differ on disk and in the code. Keeping the one from code.
# INFO:absl:Reusing dataset cifar10 (/mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2)
# INFO:absl:Constructing tf.data.Dataset cifar10 for split test, from /mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2
# INFO:absl:For 'cifar10/3.0.2': fields info.[splits, supervised_keys] differ on disk and in the code. Keeping the one from code.
# INFO:absl:Reading dataset from tfds "eurosat"
# INFO:absl:No config specified, defaulting to config: eurosat/rgb
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0
# INFO:absl:Reusing dataset eurosat (/mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0)
# INFO:absl:Constructing tf.data.Dataset eurosat for split train[:90%], from /mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0
# INFO:absl:No config specified, defaulting to config: eurosat/rgb
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0
# INFO:absl:No config specified, defaulting to config: eurosat/rgb
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0
# INFO:absl:Reusing dataset eurosat (/mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0)
# INFO:absl:Constructing tf.data.Dataset eurosat for split train[90%:], from /mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0
# INFO:absl:No config specified, defaulting to config: eurosat/rgb
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0
# INFO:absl:Reading dataset from tfds "oxford_iiit_pet"
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0
# INFO:absl:Reusing dataset oxford_iiit_pet (/mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0)
# INFO:absl:Constructing tf.data.Dataset oxford_iiit_pet for split train, from /mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0
# INFO:absl:Reusing dataset oxford_iiit_pet (/mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0)
# INFO:absl:Constructing tf.data.Dataset oxford_iiit_pet for split test[:90%], from /mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0
# INFO:absl:Reading dataset from tfds "resisc45"
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0
# INFO:absl:Reusing dataset resisc45 (/mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0)
# INFO:absl:Constructing tf.data.Dataset resisc45 for split train[10%:90%], from /mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0
# INFO:absl:Reusing dataset resisc45 (/mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0)
# INFO:absl:Constructing tf.data.Dataset resisc45 for split train[90%:], from /mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0
# INFO:absl:Reading dataset from tfds "cifar100"
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2
# INFO:absl:Reusing dataset cifar100 (/mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2)
# INFO:absl:Constructing tf.data.Dataset cifar100 for split train, from /mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2
# INFO:absl:Reusing dataset cifar100 (/mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2)
# INFO:absl:Constructing tf.data.Dataset cifar100 for split test, from /mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2
# INFO:absl:Reading dataset from tfds "cassava"
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0
# INFO:absl:Reusing dataset cassava (/mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0)
# INFO:absl:Constructing tf.data.Dataset cassava for split train, from /mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0
# INFO:absl:Reusing dataset cassava (/mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0)
# INFO:absl:Constructing tf.data.Dataset cassava for split test, from /mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0
# INFO:absl:Reading dataset from tfds "svhn_cropped"
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0
# INFO:absl:For 'svhn_cropped/3.0.0': fields info.[description, citation, module_name] differ on disk and in the code. Keeping the one from code.
# INFO:absl:Reusing dataset svhn_cropped (/mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0)
# INFO:absl:Constructing tf.data.Dataset svhn_cropped for split train, from /mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0
# INFO:absl:For 'svhn_cropped/3.0.0': fields info.[description, citation, module_name] differ on disk and in the code. Keeping the one from code.
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0
# INFO:absl:For 'svhn_cropped/3.0.0': fields info.[description, citation, module_name] differ on disk and in the code. Keeping the one from code.
# INFO:absl:Reusing dataset svhn_cropped (/mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0)
# INFO:absl:Constructing tf.data.Dataset svhn_cropped for split test, from /mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0
# INFO:absl:For 'svhn_cropped/3.0.0': fields info.[description, citation, module_name] differ on disk and in the code. Keeping the one from code.

# %%
## Load expert parameters
expert_params_ls = []

for ix, dataset in enumerate(datasets):
  logging.info(f"Loading expert models for {dataset} from {config[dataset].model_dir}.")
  raw_state = restore_checkpoint(config[dataset].model_dir)
  expert_params = {'params': raw_state['params']}
  expert_params_ls += [expert_params]
# Out:
# INFO:root:Loading expert models for colorectal_histology from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/colorectal_histology/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/.
# INFO:absl:Restoring orbax checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/colorectal_histology/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000
# INFO:absl:Restoring item from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/colorectal_histology/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:absl:Finished restoring checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/colorectal_histology/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:root:Loading expert models for cifar10 from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/cifar10/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/.
# INFO:absl:Restoring orbax checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/cifar10/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000
# INFO:absl:Restoring item from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/cifar10/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:absl:Finished restoring checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/cifar10/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:root:Loading expert models for eurosat from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/eurosat/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/.
# INFO:absl:Restoring orbax checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/eurosat/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000
# INFO:absl:Restoring item from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/eurosat/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:absl:Finished restoring checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/eurosat/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:root:Loading expert models for oxford_iiit_pet from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/oxford_iiit_pet/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/.
# INFO:absl:Restoring orbax checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/oxford_iiit_pet/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000
# INFO:absl:Restoring item from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/oxford_iiit_pet/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:absl:Finished restoring checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/oxford_iiit_pet/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:root:Loading expert models for resisc45 from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/resisc45/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/.
# INFO:absl:Restoring orbax checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/resisc45/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000
# INFO:absl:Restoring item from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/resisc45/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:absl:Finished restoring checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/resisc45/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:root:Loading expert models for cifar100 from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/cifar100/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/.
# INFO:absl:Restoring orbax checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/cifar100/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000
# INFO:absl:Restoring item from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/cifar100/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:absl:Finished restoring checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/cifar100/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:root:Loading expert models for cassava from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/cassava/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/.
# INFO:absl:Restoring orbax checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/cassava/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000
# INFO:absl:Restoring item from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/cassava/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:absl:Finished restoring checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/cassava/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:root:Loading expert models for svhn_cropped from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/svhn_cropped/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/.
# INFO:absl:Restoring orbax checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/svhn_cropped/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000
# INFO:absl:Restoring item from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/svhn_cropped/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.
# INFO:absl:Finished restoring checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/svhn_cropped/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/checkpoint_8000.

# %%
## Load init parameters
raw_state_init_a = restore_checkpoint(config.task_a_init)
init_params_a = {'params': raw_state_init_a['params']}
zeros_classifier = utils.tree_zeros_like(init_params_a['params']['classifier'])
init_params_a['params'].pop('classifier')

raw_state_init_b = restore_checkpoint(config.task_b_init)
init_params_b = {'params': raw_state_init_b['params']}
init_params_b['params'].pop('classifier')
# Out:
# INFO:absl:Restoring orbax checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/cassava/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/init/checkpoint_0
# INFO:absl:Restoring item from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/cassava/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/init/checkpoint_0.
# INFO:absl:Finished restoring checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_13/cassava/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/init/checkpoint_0.
# INFO:absl:Restoring orbax checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/cassava/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/init/checkpoint_0
# INFO:absl:Restoring item from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/cassava/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/init/checkpoint_0.
# INFO:absl:Finished restoring checkpoint from /home/ekansh/repos/share/vision-models/experiments/VGG16x2/ILSVRC_15/cassava/sgd/trained_classifier/steps_8000_500/cosine_1e-2/seed_0/init/checkpoint_0.
# {'Dense_0': {'kernel': array([[-0.00410706,  0.01246298, -0.01316439, -0.02068997,  0.00854768],
#          [ 0.00552348, -0.0216361 ,  0.00534177,  0.02177045, -0.01058934],
#          [ 0.00906   ,  0.00191369, -0.00198545, -0.00249587, -0.00434745],
#          ...,
#          [ 0.00075656, -0.00995404,  0.00848958, -0.01992465,  0.00662864],
#          [-0.00346388,  0.00515312, -0.0046915 ,  0.00792189, -0.01034135],
#          [ 0.00386668, -0.01339846,  0.01770931, -0.00042364, -0.00461111]],
#         dtype=float32)}}

# %%
ps = model_ls[0].permutation_spec()
rng = random.PRNGKey(0)

# %%
init_params_a['params']['classifier'] = zeros_classifier
init_params_b['params']['classifier'] = zeros_classifier

perm = weight_matching(rng, ps, init_params_a['params'], init_params_b['params'])
init_params_b['params'] = unfreeze(apply_permutation(ps, perm, init_params_b['params']))
# Out:
# INFO:root:0/P/encoder/Conv_1: 34.825828552246094
# INFO:root:0/P/encoder/Conv_6: 77.56377410888672
# INFO:root:0/P/encoder/Conv_3: 52.38648223876953
# INFO:root:0/P/encoder/Conv_12: 232.63577270507812
# INFO:root:0/P/encoder/Conv_0: 168.3642578125
# INFO:root:0/P/encoder/Conv_2: 39.931060791015625
# INFO:root:0/P/encoder/Conv_4: 56.01622009277344
# INFO:root:0/P/encoder/Conv_5: 64.74514770507812
# INFO:root:0/P/encoder/Dense_1: 291.359375
# INFO:root:0/P/encoder/Conv_8: 106.21080017089844
# INFO:root:0/P/encoder/Dense_0: 261.15869140625
# INFO:root:0/P/encoder/Conv_10: 137.3310546875
# INFO:root:0/P/encoder/Conv_9: 93.14303588867188
# INFO:root:0/P/encoder/Conv_11: 94.973876953125
# INFO:root:0/P/encoder/Conv_7: 71.75433349609375
# INFO:root:0/P/visual_projection: 0.0
# INFO:root:1/P/encoder/Conv_8: 22.456878662109375
# INFO:root:1/P/encoder/Conv_11: 0.0
# INFO:root:1/P/encoder/Conv_9: 3.85589599609375
# INFO:root:1/P/encoder/Conv_7: 8.4820556640625
# INFO:root:1/P/encoder/Conv_1: 114.88726806640625
# INFO:root:1/P/encoder/Dense_0: 0.0
# INFO:root:1/P/encoder/Conv_6: 48.63116455078125
# INFO:root:1/P/encoder/Conv_5: 33.22210693359375
# INFO:root:1/P/visual_projection: 0.0
# INFO:root:1/P/encoder/Conv_2: 66.62710571289062
# INFO:root:1/P/encoder/Dense_1: 27.19122314453125
# INFO:root:1/P/encoder/Conv_3: 108.61662292480469
# INFO:root:1/P/encoder/Conv_12: 18.9459228515625
# INFO:root:1/P/encoder/Conv_10: 19.23004150390625
# INFO:root:1/P/encoder/Conv_4: 239.48829650878906
# INFO:root:1/P/encoder/Conv_0: 0.46221923828125
# INFO:root:2/P/encoder/Conv_0: 0.0
# INFO:root:2/P/encoder/Dense_0: 93.747802734375
# INFO:root:2/P/encoder/Conv_3: 6.242919921875
# INFO:root:2/P/encoder/Conv_8: 10.10980224609375
# INFO:root:2/P/encoder/Conv_4: 0.31304931640625
# INFO:root:2/P/encoder/Conv_7: 121.11622619628906
# INFO:root:2/P/encoder/Conv_11: 25.026824951171875
# INFO:root:2/P/encoder/Conv_9: 13.52984619140625
# INFO:root:2/P/encoder/Conv_10: 31.821258544921875
# INFO:root:2/P/encoder/Conv_6: 59.634124755859375
# INFO:root:2/P/encoder/Conv_1: 2.0010986328125
# INFO:root:2/P/encoder/Conv_2: 6.873870849609375
# INFO:root:2/P/encoder/Dense_1: 6.2685546875
# INFO:root:2/P/encoder/Conv_12: 64.6881103515625
# INFO:root:2/P/encoder/Conv_5: 29.86297607421875
# INFO:root:2/P/visual_projection: 0.0
# INFO:root:3/P/encoder/Dense_1: 0.0
# INFO:root:3/P/visual_projection: 0.0
# INFO:root:3/P/encoder/Conv_4: 0.73291015625
# INFO:root:3/P/encoder/Conv_3: 0.31500244140625
# INFO:root:3/P/encoder/Conv_12: 0.0
# INFO:root:3/P/encoder/Conv_10: 0.0
# INFO:root:3/P/encoder/Conv_11: 74.41046142578125
# INFO:root:3/P/encoder/Conv_5: 0.047698974609375
# INFO:root:3/P/encoder/Dense_0: 53.9339599609375
# INFO:root:3/P/encoder/Conv_1: 0.005706787109375
# INFO:root:3/P/encoder/Conv_7: 19.146575927734375
# INFO:root:3/P/encoder/Conv_6: 1.29962158203125
# INFO:root:3/P/encoder/Conv_8: 106.75595092773438
# INFO:root:3/P/encoder/Conv_2: 0.111572265625
# INFO:root:3/P/encoder/Conv_9: 109.95733642578125
# INFO:root:3/P/encoder/Conv_0: 0.021942138671875
# INFO:root:4/P/encoder/Conv_6: 0.0
# INFO:root:4/P/encoder/Conv_11: 0.0
# INFO:root:4/P/encoder/Conv_10: 131.90597534179688
# INFO:root:4/P/encoder/Conv_1: 0.0
# INFO:root:4/P/encoder/Conv_7: 5.7403564453125
# INFO:root:4/P/encoder/Dense_0: 0.0
# INFO:root:4/P/encoder/Conv_2: 0.0
# INFO:root:4/P/encoder/Conv_12: 6.1221923828125
# INFO:root:4/P/encoder/Conv_5: 0.079986572265625
# INFO:root:4/P/encoder/Conv_9: 11.84088134765625
# INFO:root:4/P/encoder/Conv_0: 0.0
# INFO:root:4/P/visual_projection: 0.0
# INFO:root:4/P/encoder/Dense_1: 2.94293212890625
# INFO:root:4/P/encoder/Conv_8: 12.83294677734375
# INFO:root:4/P/encoder/Conv_3: -3.0517578125e-05
# INFO:root:4/P/encoder/Conv_4: 0.003204345703125
# INFO:root:5/P/encoder/Conv_1: 0.0
# INFO:root:5/P/encoder/Conv_11: 24.505889892578125
# INFO:root:5/P/encoder/Conv_8: 0.0
# INFO:root:5/P/encoder/Dense_0: 7.150146484375
# INFO:root:5/P/encoder/Dense_1: 1.13604736328125
# INFO:root:5/P/encoder/Conv_9: 0.7091064453125
# INFO:root:5/P/encoder/Conv_3: 0.009613037109375
# INFO:root:5/P/encoder/Conv_0: 0.0
# INFO:root:5/P/encoder/Conv_2: 0.0
# INFO:root:5/P/encoder/Conv_6: 0.215789794921875
# INFO:root:5/P/encoder/Conv_12: 0.74725341796875
# INFO:root:5/P/encoder/Conv_4: 0.008941650390625
# INFO:root:5/P/encoder/Conv_5: 0.09051513671875
# INFO:root:5/P/encoder/Conv_10: 4.53228759765625
# INFO:root:5/P/encoder/Conv_7: 1.122802734375
# INFO:root:5/P/visual_projection: 0.0
# INFO:root:6/P/encoder/Conv_0: 0.0
# INFO:root:6/P/visual_projection: 0.0
# INFO:root:6/P/encoder/Dense_0: 1.89422607421875
# INFO:root:6/P/encoder/Conv_11: 1.538543701171875
# INFO:root:6/P/encoder/Conv_3: 0.0
# INFO:root:6/P/encoder/Conv_5: 0.0
# INFO:root:6/P/encoder/Conv_7: 0.0
# INFO:root:6/P/encoder/Conv_6: 0.034027099609375
# INFO:root:6/P/encoder/Conv_9: 0.3895263671875
# INFO:root:6/P/encoder/Dense_1: 0.63385009765625
# INFO:root:6/P/encoder/Conv_4: 0.1185302734375
# INFO:root:6/P/encoder/Conv_10: 0.48345947265625
# INFO:root:6/P/encoder/Conv_2: 0.0
# INFO:root:6/P/encoder/Conv_12: 0.0048828125
# INFO:root:6/P/encoder/Conv_1: 0.0
# INFO:root:6/P/encoder/Conv_8: 0.504638671875
# INFO:root:7/P/encoder/Conv_11: 0.375518798828125
# INFO:root:7/P/encoder/Conv_7: 0.02740478515625
# INFO:root:7/P/encoder/Conv_3: 0.0
# INFO:root:7/P/encoder/Conv_10: 0.2398681640625
# INFO:root:7/P/visual_projection: 0.0
# INFO:root:7/P/encoder/Conv_2: 0.0
# INFO:root:7/P/encoder/Dense_0: 0.09893798828125
# INFO:root:7/P/encoder/Dense_1: 0.27252197265625
# INFO:root:7/P/encoder/Conv_0: 0.0
# INFO:root:7/P/encoder/Conv_5: 0.0098876953125
# INFO:root:7/P/encoder/Conv_6: 0.007568359375
# INFO:root:7/P/encoder/Conv_1: 0.0
# INFO:root:7/P/encoder/Conv_8: 0.0
# INFO:root:7/P/encoder/Conv_9: 0.19635009765625
# INFO:root:7/P/encoder/Conv_12: 0.0
# INFO:root:7/P/encoder/Conv_4: 3.0517578125e-05
# INFO:root:8/P/encoder/Conv_6: 0.0
# INFO:root:8/P/encoder/Conv_2: 0.0
# INFO:root:8/P/encoder/Conv_7: 0.0
# INFO:root:8/P/encoder/Dense_0: 4.23431396484375
# INFO:root:8/P/visual_projection: 0.0
# INFO:root:8/P/encoder/Conv_4: 0.0
# INFO:root:8/P/encoder/Conv_1: 0.0
# INFO:root:8/P/encoder/Dense_1: 0.33819580078125
# INFO:root:8/P/encoder/Conv_11: 0.131805419921875
# INFO:root:8/P/encoder/Conv_0: 0.0
# INFO:root:8/P/encoder/Conv_8: 0.06658935546875
# INFO:root:8/P/encoder/Conv_10: 0.222900390625
# INFO:root:8/P/encoder/Conv_12: 0.068359375
# INFO:root:8/P/encoder/Conv_9: 0.04583740234375
# INFO:root:8/P/encoder/Conv_3: 0.0
# INFO:root:8/P/encoder/Conv_5: 0.0
# INFO:root:9/P/visual_projection: 0.0
# INFO:root:9/P/encoder/Conv_0: 0.0
# INFO:root:9/P/encoder/Conv_6: 0.0
# INFO:root:9/P/encoder/Dense_1: 0.0
# INFO:root:9/P/encoder/Conv_4: 0.0
# INFO:root:9/P/encoder/Conv_1: 0.0
# INFO:root:9/P/encoder/Conv_12: 0.0
# INFO:root:9/P/encoder/Conv_3: 0.0
# INFO:root:9/P/encoder/Conv_10: 0.00762939453125
# INFO:root:9/P/encoder/Conv_5: 0.0
# INFO:root:9/P/encoder/Conv_7: 0.0125732421875
# INFO:root:9/P/encoder/Conv_2: 0.0
# INFO:root:9/P/encoder/Conv_11: 0.33221435546875
# INFO:root:9/P/encoder/Conv_8: 0.0545654296875
# INFO:root:9/P/encoder/Dense_0: 0.529052734375
# INFO:root:9/P/encoder/Conv_9: 0.01165771484375
# INFO:root:10/P/encoder/Dense_0: 0.0
# INFO:root:10/P/encoder/Conv_0: 0.0
# INFO:root:10/P/encoder/Conv_11: 0.0
# INFO:root:10/P/encoder/Dense_1: 0.25555419921875
# INFO:root:10/P/encoder/Conv_9: 0.0
# INFO:root:10/P/encoder/Conv_4: 0.0
# INFO:root:10/P/encoder/Conv_8: 0.00286865234375
# INFO:root:10/P/encoder/Conv_7: 0.06402587890625
# INFO:root:10/P/encoder/Conv_1: 0.0
# INFO:root:10/P/encoder/Conv_6: 0.0
# INFO:root:10/P/visual_projection: 0.0
# INFO:root:10/P/encoder/Conv_10: 0.04583740234375
# INFO:root:10/P/encoder/Conv_3: 0.0
# INFO:root:10/P/encoder/Conv_12: 0.00762939453125
# INFO:root:10/P/encoder/Conv_5: 0.0
# INFO:root:10/P/encoder/Conv_2: 0.0
# INFO:root:11/P/encoder/Conv_6: 0.0
# INFO:root:11/P/encoder/Conv_3: 0.0
# INFO:root:11/P/encoder/Conv_12: 0.0
# INFO:root:11/P/encoder/Dense_1: 0.0
# INFO:root:11/P/encoder/Conv_11: 0.04278564453125
# INFO:root:11/P/encoder/Conv_7: 0.0
# INFO:root:11/P/encoder/Conv_2: 0.0
# INFO:root:11/P/encoder/Conv_5: 0.0
# INFO:root:11/P/encoder/Conv_4: 0.0
# INFO:root:11/P/encoder/Conv_8: 0.00836181640625
# INFO:root:11/P/encoder/Conv_0: 0.0
# INFO:root:11/P/encoder/Dense_0: 0.05828857421875
# INFO:root:11/P/visual_projection: 0.0
# INFO:root:11/P/encoder/Conv_9: 0.0460205078125
# INFO:root:11/P/encoder/Conv_1: 0.0
# INFO:root:11/P/encoder/Conv_10: 0.10595703125
# INFO:root:12/P/encoder/Conv_3: 0.0
# INFO:root:12/P/encoder/Conv_4: 0.0
# INFO:root:12/P/encoder/Conv_6: 0.0
# INFO:root:12/P/encoder/Conv_8: 0.0
# INFO:root:12/P/encoder/Dense_0: 0.0
# INFO:root:12/P/encoder/Conv_2: 0.0
# INFO:root:12/P/encoder/Conv_5: 0.0
# INFO:root:12/P/encoder/Conv_11: 0.02978515625
# INFO:root:12/P/encoder/Conv_10: 0.01153564453125
# INFO:root:12/P/encoder/Conv_1: 0.0
# INFO:root:12/P/encoder/Conv_12: 0.00042724609375
# INFO:root:12/P/encoder/Dense_1: 0.0765380859375
# INFO:root:12/P/encoder/Conv_7: 0.07183837890625
# INFO:root:12/P/encoder/Conv_0: 0.0
# INFO:root:12/P/encoder/Conv_9: 0.0120849609375
# INFO:root:12/P/visual_projection: 0.0
# INFO:root:13/P/encoder/Conv_12: 0.0
# INFO:root:13/P/encoder/Conv_7: 0.0
# INFO:root:13/P/encoder/Conv_2: 0.0
# INFO:root:13/P/encoder/Conv_11: 0.037567138671875
# INFO:root:13/P/encoder/Conv_9: 0.0
# INFO:root:13/P/encoder/Dense_0: 0.069580078125
# INFO:root:13/P/encoder/Conv_1: 0.0
# INFO:root:13/P/encoder/Conv_6: 0.0
# INFO:root:13/P/encoder/Conv_3: 0.0
# INFO:root:13/P/encoder/Conv_5: 0.0
# INFO:root:13/P/encoder/Dense_1: 0.10211181640625
# INFO:root:13/P/visual_projection: 0.0
# INFO:root:13/P/encoder/Conv_0: 0.0
# INFO:root:13/P/encoder/Conv_4: 0.0
# INFO:root:13/P/encoder/Conv_10: 0.00958251953125
# INFO:root:13/P/encoder/Conv_8: 0.0223388671875
# INFO:root:14/P/encoder/Conv_9: 0.01934814453125
# INFO:root:14/P/encoder/Conv_2: 0.0
# INFO:root:14/P/encoder/Dense_1: 0.0
# INFO:root:14/P/encoder/Dense_0: 0.0018310546875
# INFO:root:14/P/encoder/Conv_3: 0.0
# INFO:root:14/P/encoder/Conv_10: 0.02447509765625
# INFO:root:14/P/encoder/Conv_1: 0.0
# INFO:root:14/P/encoder/Conv_4: 0.0
# INFO:root:14/P/encoder/Conv_7: 0.01513671875
# INFO:root:14/P/encoder/Conv_11: 0.05084228515625
# INFO:root:14/P/encoder/Conv_6: 0.0
# INFO:root:14/P/encoder/Conv_8: 0.0135498046875
# INFO:root:14/P/encoder/Conv_0: 0.0
# INFO:root:14/P/encoder/Conv_5: 0.0
# INFO:root:14/P/encoder/Conv_12: 0.00390625
# INFO:root:14/P/visual_projection: 0.0
# INFO:root:15/P/encoder/Dense_1: 0.005126953125
# INFO:root:15/P/encoder/Conv_4: 0.0
# INFO:root:15/P/encoder/Conv_11: 0.07666015625
# INFO:root:15/P/encoder/Conv_8: 0.0
# INFO:root:15/P/encoder/Conv_6: 0.0
# INFO:root:15/P/encoder/Conv_10: 0.00567626953125
# INFO:root:15/P/encoder/Dense_0: 0.077392578125
# INFO:root:15/P/encoder/Conv_12: 0.0
# INFO:root:15/P/visual_projection: 0.0
# INFO:root:15/P/encoder/Conv_5: 0.0
# INFO:root:15/P/encoder/Conv_0: 0.0
# INFO:root:15/P/encoder/Conv_3: 0.0
# INFO:root:15/P/encoder/Conv_1: 0.0
# INFO:root:15/P/encoder/Conv_9: 0.0628662109375
# INFO:root:15/P/encoder/Conv_2: 0.0
# INFO:root:15/P/encoder/Conv_7: 0.0006103515625
# INFO:root:16/P/encoder/Conv_2: 0.0
# INFO:root:16/P/encoder/Conv_10: 0.0
# INFO:root:16/P/encoder/Conv_5: 0.0
# INFO:root:16/P/encoder/Dense_0: 0.0
# INFO:root:16/P/encoder/Conv_6: 0.0
# INFO:root:16/P/encoder/Conv_11: 0.0059814453125
# INFO:root:16/P/encoder/Conv_3: 0.0
# INFO:root:16/P/encoder/Conv_0: 0.0
# INFO:root:16/P/encoder/Conv_9: 0.0
# INFO:root:16/P/visual_projection: 0.0
# INFO:root:16/P/encoder/Conv_8: 0.0076904296875
# INFO:root:16/P/encoder/Dense_1: 0.123779296875
# INFO:root:16/P/encoder/Conv_4: 0.0
# INFO:root:16/P/encoder/Conv_12: 0.0
# INFO:root:16/P/encoder/Conv_7: 0.0325927734375
# INFO:root:16/P/encoder/Conv_1: 0.0
# INFO:root:17/P/encoder/Conv_2: 0.0
# INFO:root:17/P/encoder/Conv_4: 0.0
# INFO:root:17/P/encoder/Conv_1: 0.0
# INFO:root:17/P/encoder/Conv_3: 0.0
# INFO:root:17/P/encoder/Conv_6: 0.0
# INFO:root:17/P/encoder/Conv_9: 0.0
# INFO:root:17/P/encoder/Dense_1: 0.0
# INFO:root:17/P/encoder/Conv_12: 0.0
# INFO:root:17/P/encoder/Dense_0: 0.04119873046875
# INFO:root:17/P/encoder/Conv_10: 0.0426025390625
# INFO:root:17/P/encoder/Conv_8: 0.0086669921875
# INFO:root:17/P/encoder/Conv_11: 0.039093017578125
# INFO:root:17/P/visual_projection: 0.0
# INFO:root:17/P/encoder/Conv_0: 0.0
# INFO:root:17/P/encoder/Conv_5: 0.0
# INFO:root:17/P/encoder/Conv_7: 0.0
# INFO:root:18/P/encoder/Conv_2: 0.0
# INFO:root:18/P/encoder/Conv_9: 0.0040283203125
# INFO:root:18/P/encoder/Conv_1: 0.0
# INFO:root:18/P/encoder/Dense_0: 0.0
# INFO:root:18/P/encoder/Dense_1: 0.09210205078125
# INFO:root:18/P/encoder/Conv_6: 0.0
# INFO:root:18/P/encoder/Conv_8: 0.01287841796875
# INFO:root:18/P/encoder/Conv_10: 0.00396728515625
# INFO:root:18/P/visual_projection: 0.0
# INFO:root:18/P/encoder/Conv_12: 0.00531005859375
# INFO:root:18/P/encoder/Conv_4: 0.0
# INFO:root:18/P/encoder/Conv_5: 0.0
# INFO:root:18/P/encoder/Conv_0: 0.0
# INFO:root:18/P/encoder/Conv_3: 0.0
# INFO:root:18/P/encoder/Conv_7: 0.00140380859375
# INFO:root:18/P/encoder/Conv_11: 0.02471923828125
# INFO:root:19/P/encoder/Conv_10: 0.00042724609375
# INFO:root:19/P/encoder/Conv_7: 0.0
# INFO:root:19/P/encoder/Conv_5: 0.0
# INFO:root:19/P/encoder/Conv_8: 0.0
# INFO:root:19/P/encoder/Conv_12: 0.0
# INFO:root:19/P/encoder/Conv_1: 0.0
# INFO:root:19/P/encoder/Dense_0: 0.0369873046875
# INFO:root:19/P/encoder/Conv_0: 0.0
# INFO:root:19/P/encoder/Conv_6: 0.0
# INFO:root:19/P/visual_projection: 0.0
# INFO:root:19/P/encoder/Conv_9: 0.0
# INFO:root:19/P/encoder/Conv_2: 0.0
# INFO:root:19/P/encoder/Conv_4: 0.0
# INFO:root:19/P/encoder/Conv_11: 3.0517578125e-05
# INFO:root:19/P/encoder/Dense_1: 0.06829833984375
# INFO:root:19/P/encoder/Conv_3: 0.0
# INFO:root:20/P/encoder/Conv_9: 0.0
# INFO:root:20/P/encoder/Conv_12: 0.0
# INFO:root:20/P/encoder/Conv_11: 0.0
# INFO:root:20/P/encoder/Dense_1: 0.0
# INFO:root:20/P/encoder/Conv_7: 0.0
# INFO:root:20/P/encoder/Conv_3: 0.0
# INFO:root:20/P/encoder/Conv_5: 0.0
# INFO:root:20/P/encoder/Dense_0: 0.00384521484375
# INFO:root:20/P/encoder/Conv_6: 0.0
# INFO:root:20/P/encoder/Conv_0: 0.0
# INFO:root:20/P/encoder/Conv_1: 0.0
# INFO:root:20/P/encoder/Conv_8: 0.0
# INFO:root:20/P/visual_projection: 0.0
# INFO:root:20/P/encoder/Conv_2: 0.0
# INFO:root:20/P/encoder/Conv_4: 0.0
# INFO:root:20/P/encoder/Conv_10: 0.0
# INFO:root:21/P/encoder/Conv_4: 0.0
# INFO:root:21/P/encoder/Conv_9: 0.0
# INFO:root:21/P/encoder/Conv_2: 0.0
# INFO:root:21/P/encoder/Conv_1: 0.0
# INFO:root:21/P/encoder/Conv_7: 0.0
# INFO:root:21/P/encoder/Dense_1: 0.00946044921875
# INFO:root:21/P/encoder/Conv_8: 0.0
# INFO:root:21/P/encoder/Conv_0: 0.0
# INFO:root:21/P/visual_projection: 0.0
# INFO:root:21/P/encoder/Conv_3: 0.0
# INFO:root:21/P/encoder/Conv_5: 0.0
# INFO:root:21/P/encoder/Conv_10: 0.0
# INFO:root:21/P/encoder/Dense_0: 0.0
# INFO:root:21/P/encoder/Conv_11: 0.0
# INFO:root:21/P/encoder/Conv_6: 0.0
# INFO:root:21/P/encoder/Conv_12: 6.103515625e-05
# INFO:root:22/P/encoder/Conv_11: 0.0
# INFO:root:22/P/encoder/Conv_12: 0.0
# INFO:root:22/P/encoder/Conv_7: 0.0
# INFO:root:22/P/encoder/Conv_5: 0.0
# INFO:root:22/P/encoder/Conv_4: 0.0
# INFO:root:22/P/encoder/Conv_8: 0.0
# INFO:root:22/P/encoder/Conv_9: 0.0
# INFO:root:22/P/encoder/Conv_0: 0.0
# INFO:root:22/P/encoder/Conv_3: 0.0
# INFO:root:22/P/encoder/Dense_1: 0.0
# INFO:root:22/P/encoder/Conv_10: 0.0
# INFO:root:22/P/visual_projection: 0.0
# INFO:root:22/P/encoder/Conv_1: 0.0
# INFO:root:22/P/encoder/Conv_6: 0.0
# INFO:root:22/P/encoder/Dense_0: 0.0
# INFO:root:22/P/encoder/Conv_2: 0.0

# %%
# permute the models from tasks b
for ix in range(int(len(datasets)/2), len(datasets)):
  expert_params_ls[ix]['params'] = unfreeze(apply_permutation(ps, perm, expert_params_ls[ix]['params']))

# %%
init_params = utils.lerp(0.5, init_params_a, init_params_b)

# %%
init_params['params'].pop('classifier')
classifiers_ls = [expert_params['params'].pop('classifier') for expert_params in expert_params_ls]

# %%
## Expert accuracies:
expert_loss = {}
expert_accs = {}

for ix, dataset in enumerate(datasets):
  expert_params_ls[ix]['params']['classifier'] = classifiers_ls[ix]
  loss, accuracy = compute_loss_and_accuracy(model_ls[ix].apply, expert_params_ls[ix], ds_test_ls[ix])
  expert_loss[dataset] = loss
  expert_accs[dataset] = accuracy
  expert_params_ls[ix]['params'].pop('classifier')
  print(f"{dataset} expert accuracy = {accuracy}")
  print(f"{dataset} expert loss = {loss}")
# Out:
# 2024-10-11 14:29:57.081525: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# colorectal_histology expert accuracy = 0.96875
# colorectal_histology expert loss = 0.1508624404668808
# 2024-10-11 14:30:04.268895: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# cifar10 expert accuracy = 0.9690504670143127
# cifar10 expert loss = 0.12621986865997314
# 2024-10-11 14:30:06.598099: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# eurosat expert accuracy = 0.984747052192688
# eurosat expert loss = 0.07891904562711716
# 2024-10-11 14:30:09.367479: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# oxford_iiit_pet expert accuracy = 0.8653125166893005
# oxford_iiit_pet expert loss = 0.8615166544914246
# 2024-10-11 14:30:11.097361: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# resisc45 expert accuracy = 0.931640625
# resisc45 expert loss = 0.305586576461792
# 2024-10-11 14:30:16.824880: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# cifar100 expert accuracy = 0.8235176205635071
# cifar100 expert loss = 0.8736114501953125
# 2024-10-11 14:30:18.426340: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# cassava expert accuracy = 0.8504464030265808
# cassava expert loss = 0.9811003804206848
# 2024-10-11 14:30:32.258150: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# svhn_cropped expert accuracy = 0.9509313702583313
# svhn_cropped expert loss = 0.17739953100681305

# %%
tall_mask = False
task_vectors = [utils.tree_subtract(params['params'], init_params['params']) for params  in expert_params_ls]  

## Task-arithmetic model-merging: 
# print("TA")
# lam = 0.4
# t_MTL = merging.compute_task_arithmetic_vector(task_vectors, lam)
# merged_params  = {'params': utils.tree_add(t_MTL, init_params['params'])}

## TIES model-merging: 
# print("TIES")
# lam=0.8
# t_MTL = merging.compute_ties_vector(task_vectors, lam)
# merged_params  = {'params': utils.tree_add(t_MTL, init_params['params'])}

## TA+TALL model-merging: 
print("TA+TALL")
lam=0.5
t_MTL = merging.compute_ties_vector(task_vectors, lam)
t_masks_ls = [merging.compute_tall_mask(task_vector, t_MTL) for task_vector in task_vectors]
tall_mask = True

## TIES+TALL model-merging: 
# print("TIES")
# lam=0.8
# t_MTL = merging.compute_ties_vector(task_vectors, lam)
# t_masks_ls = [merging.compute_tall_mask(task_vector, t_MTL) for task_vector in task_vectors]
# tall_mask = True
# Out:
# TA+TALL

# %%
# Evaluation

merged_accuracies = {}
merged_normalized_accuracies = {}
for ix, dataset in enumerate(datasets):
  if tall_mask:
    merged_params = {'params' : utils.tree_add(init_params['params'], apply_mask(t_MTL, t_masks_ls[ix]))}
  merged_params['params']['classifier'] = classifiers_ls[ix]
  loss, accuracy = compute_loss_and_accuracy(model_ls[ix].apply, merged_params, ds_test_ls[ix])
  merged_accuracies[dataset] = accuracy
  merged_normalized_accuracies[dataset] = norm_acc(accuracy, expert_accs[dataset])
  merged_params['params'].pop('classifier')
  print(f'{dataset}')
  print(f"merged accuracy = {accuracy}")
  print(f"normalized accuracy = {norm_acc(accuracy, expert_accs[dataset])}")
# Out:
# 2024-10-11 14:31:05.045035: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# colorectal_histology
# merged accuracy = 0.5390625
# normalized accuracy = 0.5564516186714172
# 2024-10-11 14:31:09.691860: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# cifar10
# merged accuracy = 0.7926682829856873
# normalized accuracy = 0.8179845213890076
# 2024-10-11 14:31:11.121097: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# eurosat
# merged accuracy = 0.5279017686843872
# normalized accuracy = 0.5360785722732544
# 2024-10-11 14:31:12.860343: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# oxford_iiit_pet
# merged accuracy = 0.37031251192092896
# normalized accuracy = 0.4279523491859436
# 2024-10-11 14:31:14.508441: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# resisc45
# merged accuracy = 0.3167317807674408
# normalized accuracy = 0.33997204899787903
# 2024-10-11 14:31:19.664327: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# cifar100
# merged accuracy = 0.4151642620563507
# normalized accuracy = 0.504135251045227
# 2024-10-11 14:31:20.665976: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# cassava
# merged accuracy = 0.5245535969734192
# normalized accuracy = 0.616797924041748
# 2024-10-11 14:31:34.061338: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# svhn_cropped
# merged accuracy = 0.7521551847457886
# normalized accuracy = 0.7909668684005737

# %%
## Compute output statistics for expert parameters
expert_batch_stats_ls = []
rng = random.PRNGKey(0)
for ix, dataset in enumerate(datasets):
  expert_params_ls[ix]['params']['classifier'] = classifiers_ls[ix]
  params_tracker = models.load_from_source(model_tracker_ls[ix].initialization(rng, (1, crop, crop, 3)), {'params': expert_params_ls[ix]['params']})
  params_tracker = update_batch_stats(model_tracker_ls[ix].apply, params_tracker, ds_train_ls[ix], nbatches=500)
  expert_batch_stats_ls += [params_tracker['batch_stats']]
  expert_params_ls[ix]['params'].pop('classifier')
# Out:
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 2024-10-11 14:33:38.172032: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 2024-10-11 14:33:40.155014: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:33:42.308666: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 334159 bytes after encountering the first element of size 334159 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 2024-10-11 14:33:46.555984: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:33:48.710779: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:33:50.865704: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# 2024-10-11 14:33:53.063179: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:33:55.168090: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:33:57.498340: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:33:59.465779: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# 2024-10-11 14:34:01.559223: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:34:03.691467: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 334159 bytes after encountering the first element of size 334159 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:34:05.829766: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:34:08.032767: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:34:10.345143: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment

# %%
tact_accuracies = {}
tact_normalized_accuracies = {}

for ix, dataset in enumerate(datasets):
  print(f"Computing TACT accuracy for {dataset}")
  if tall_mask:
    merged_params = {'params' : utils.tree_add(init_params['params'], apply_mask(t_MTL, t_masks_ls[ix]))}
  merged_params_tact = models.load_from_source(model_repaired_ls[ix].initialization(rng, (1, crop, crop, 3)), merged_params)
  merged_params_tact = models.set_batch_norm_params_from_batch_stats(merged_params_tact, expert_batch_stats_ls[ix])
  merged_params_tact['params']['classifier'] = classifiers_ls[ix]
  merged_params_tact = update_batch_stats(model_repaired_ls[ix].apply, merged_params_tact,  ds_train_ls[ix], nbatches=500)
  loss, accuracy = compute_loss_and_accuracy(model_repaired_ls[ix].apply, merged_params_tact, ds_test_ls[ix])
  tact_accuracies[dataset] = accuracy
  tact_normalized_accuracies[dataset] = norm_acc(accuracy, expert_accs[dataset])
  print(f"accuracy = {tact_accuracies[dataset]}")
  print(f"normalized accuracy = {tact_normalized_accuracies[dataset]}")
# Out:
# Computing TACT accuracy for colorectal_histology
# 2024-10-11 14:37:39.344610: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.8697916865348816
# normalized accuracy = 0.8978495001792908
# Computing TACT accuracy for cifar10
# 2024-10-11 14:38:24.851613: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.9259815812110901
# normalized accuracy = 0.9555555582046509
# Computing TACT accuracy for eurosat
# 2024-10-11 14:39:06.483472: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.9226190447807312
# normalized accuracy = 0.9369096755981445
# Computing TACT accuracy for oxford_iiit_pet
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:39:29.477829: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 329372 bytes after encountering the first element of size 329372 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: premature end of data segment
# 2024-10-11 14:39:31.692513: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 329372 bytes after encountering the first element of size 329372 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:39:33.906915: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# 2024-10-11 14:39:36.060019: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 248348 bytes after encountering the first element of size 248348 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 2024-10-11 14:39:38.274819: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 329372 bytes after encountering the first element of size 329372 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:39:40.490297: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 246706 bytes after encountering the first element of size 246706 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:39:42.706562: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 329372 bytes after encountering the first element of size 329372 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: premature end of data segment
# 2024-10-11 14:39:44.857008: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 329372 bytes after encountering the first element of size 329372 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:39:49.184745: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.7215625047683716
# normalized accuracy = 0.8338750600814819
# Computing TACT accuracy for resisc45
# 2024-10-11 14:40:31.816796: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.744140625
# normalized accuracy = 0.7987421154975891
# Computing TACT accuracy for cifar100
# 2024-10-11 14:41:18.211518: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.6824919581413269
# normalized accuracy = 0.8287521004676819
# Computing TACT accuracy for cassava
# 2024-10-11 14:42:00.114473: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.7287946343421936
# normalized accuracy = 0.8569554090499878
# Computing TACT accuracy for svhn_cropped
# 2024-10-11 14:42:54.336880: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.8906635046005249
# normalized accuracy = 0.9366222620010376

# %%
## Compute REPAIR batch_stats:
ds_merged = input_pipeline.get_unlabelled_datasets(config, datasets, 'train[:1000]', 128, repeats=None)

repair_expert_batch_stats_ls = []
for ix, dataset in enumerate(datasets):
  expert_params_ls[ix]['params']['classifier'] = classifiers_ls[ix]
  params_tracker = models.load_from_source(model_tracker_ls[ix].initialization(rng, (1, crop, crop, 3)), {'params': expert_params_ls[ix]['params']})
  params_tracker = update_batch_stats(model_tracker_ls[ix].apply, params_tracker, ds_merged, nbatches=500)
  repair_expert_batch_stats_ls += [params_tracker['batch_stats']]


merged_batch_stats = utils.merge_batch_stats(repair_expert_batch_stats_ls)
# Out:
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0
# INFO:absl:Reusing dataset colorectal_histology (/mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0)
# INFO:absl:Constructing tf.data.Dataset colorectal_histology for split train[:1000], from /mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/colorectal_histology/2.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2
# INFO:absl:For 'cifar10/3.0.2': fields info.[splits, supervised_keys] differ on disk and in the code. Keeping the one from code.
# INFO:absl:Reusing dataset cifar10 (/mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2)
# INFO:absl:Constructing tf.data.Dataset cifar10 for split train[:1000], from /mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar10/3.0.2
# INFO:absl:For 'cifar10/3.0.2': fields info.[splits, supervised_keys] differ on disk and in the code. Keeping the one from code.
# INFO:absl:No config specified, defaulting to config: eurosat/rgb
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0
# INFO:absl:Reusing dataset eurosat (/mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0)
# INFO:absl:Constructing tf.data.Dataset eurosat for split train[:1000], from /mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0
# INFO:absl:No config specified, defaulting to config: eurosat/rgb
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/eurosat/rgb/2.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0
# INFO:absl:Reusing dataset oxford_iiit_pet (/mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0)
# INFO:absl:Constructing tf.data.Dataset oxford_iiit_pet for split train[:1000], from /mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/oxford_iiit_pet/3.2.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0
# INFO:absl:Reusing dataset resisc45 (/mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0)
# INFO:absl:Constructing tf.data.Dataset resisc45 for split train[:1000], from /mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/resisc45/3.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2
# INFO:absl:Reusing dataset cifar100 (/mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2)
# INFO:absl:Constructing tf.data.Dataset cifar100 for split train[:1000], from /mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cifar100/3.0.2
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0
# INFO:absl:Reusing dataset cassava (/mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0)
# INFO:absl:Constructing tf.data.Dataset cassava for split train[:1000], from /mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/cassava/0.1.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0
# INFO:absl:For 'svhn_cropped/3.0.0': fields info.[description, citation, module_name] differ on disk and in the code. Keeping the one from code.
# INFO:absl:Reusing dataset svhn_cropped (/mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0)
# INFO:absl:Constructing tf.data.Dataset svhn_cropped for split train[:1000], from /mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0
# INFO:absl:Load dataset info from /mnt/MintStorage/data/tensorflow_datasets/svhn_cropped/3.0.0
# INFO:absl:For 'svhn_cropped/3.0.0': fields info.[description, citation, module_name] differ on disk and in the code. Keeping the one from code.
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:43:08.980405: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:11.898764: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:43:12.519031: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:13.091472: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:13.691947: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:14.288136: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:14.885434: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:15.410322: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:16.008695: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:16.610851: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:43:17.207006: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:17.803484: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:18.331124: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:18.942069: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:19.524864: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:20.122368: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:20.719941: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:21.249113: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:43:21.870996: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:22.446141: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:23.045427: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:23.638195: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:24.235172: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:24.760899: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:25.358223: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:25.961305: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:43:26.556735: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:27.152802: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:27.682235: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:28.292732: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:28.875019: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:29.472431: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:30.069489: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:30.599031: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:43:31.214376: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:31.791744: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:32.392951: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:32.988482: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:33.585247: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:43:34.109825: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:44:02.196890: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:04.502456: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:05.102560: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:44:05.696575: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:06.290757: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:06.817679: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:07.426492: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:08.006132: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:08.601185: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:09.196647: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:09.723445: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:44:10.342542: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:10.911755: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:11.509582: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:12.103076: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:12.697854: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:13.220644: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:44:41.236102: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:44.138713: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:44:44.732777: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:45.851691: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:47.038072: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:47.633034: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:48.227555: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:48.755021: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:44:49.371000: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:49.940896: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:50.540635: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:51.132899: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:51.726314: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:44:52.248572: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:45:18.187434: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:18.714248: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:45:19.328436: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:20.492689: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:21.086011: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:21.678811: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:22.201012: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:22.794256: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:23.393579: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 666060 bytes after encountering the first element of size 666060 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:45:23.986070: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:24.578164: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:25.104456: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:25.710504: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:26.290524: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:26.884564: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:27.478582: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:28.004688: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:45:28.616914: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:29.190047: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:29.787863: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:30.379421: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:30.973222: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:31.495859: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:45:57.677233: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:45:58.296500: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:45:59.460413: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:00.647203: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:01.172699: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:01.762315: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:02.361612: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:46:02.954048: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:03.546681: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:04.072368: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:04.679681: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:05.257309: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:05.851926: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:06.445909: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:06.972428: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:46:07.590930: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:08.157840: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:08.754796: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:09.348113: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:09.941703: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:10.463420: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:46:36.726031: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:46:37.911598: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:38.509366: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:39.102691: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:39.696389: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:46:40.218992: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# ...
# 2024-10-11 14:47:25.663561: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:26.230865: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:26.828676: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:27.421379: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:28.014872: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:28.537088: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:47:44.886688: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:45.413317: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:47:46.031680: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:46.599581: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:47.197358: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:47.789934: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:48.383411: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:48.905815: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:49.500911: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:50.100274: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:47:50.691991: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:51.285178: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:51.812050: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:52.418654: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:52.998741: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:53.593017: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:54.187813: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:54.714232: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:47:55.334860: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:55.901388: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:56.499223: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:57.092068: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:57.685876: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:58.208625: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:58.803022: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:47:59.402100: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:47:59.995108: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:00.588350: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:01.114941: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:01.722628: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:02.302203: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:02.897034: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:03.491779: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:04.019137: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:48:04.637863: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:05.205696: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:05.803289: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:06.396898: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:06.991408: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:07.514161: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size

# %%
repair_accuracies = {}
repair_normalized_accuracies = {}

if not tall_mask:
  # Update the batch stats of the shared merged params
  merged_params_repair = models.load_from_source(model_repaired_ls[ix].initialization(rng, (1, crop, crop, 3)), merged_params)
  merged_params_repair = models.set_batch_norm_params_from_batch_stats(merged_params_repair, merged_batch_stats)
  merged_params_repair = update_batch_stats(model_repaired_ls[ix].apply, merged_params_repair,  ds_merged, nbatches=500)

for ix, dataset in enumerate(datasets):
  print(f"Computing REPAIR accuracy for {dataset}")
  if tall_mask:
    merged_params = {'params' : utils.tree_add(init_params['params'], apply_mask(t_MTL, t_masks_ls[ix]))}
    merged_params_repair = models.load_from_source(model_repaired_ls[ix].initialization(rng, (1, crop, crop, 3)), merged_params)
    merged_params_repair = models.set_batch_norm_params_from_batch_stats(merged_params_repair, merged_batch_stats)
    merged_params_repair = update_batch_stats(model_repaired_ls[ix].apply, merged_params_repair,  ds_merged, nbatches=500)

  merged_params_repair['params']['classifier'] = classifiers_ls[ix]
  loss, accuracy = compute_loss_and_accuracy(model_repaired_ls[ix].apply, merged_params_repair, ds_test_ls[ix])
  repair_accuracies[dataset] = accuracy
  repair_normalized_accuracies[dataset] = norm_acc(accuracy, expert_accs[dataset])
  print(f"accuracy = {repair_accuracies[dataset]}")
  print(f"normalized accuracy = {repair_normalized_accuracies[dataset]}")
# Out:
# Computing REPAIR accuracy for colorectal_histology
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:48:27.019972: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:28.231778: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:29.985328: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:48:30.589819: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:31.733869: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:32.355355: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:32.945150: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:33.552679: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:34.160005: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:34.698601: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:48:35.330772: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:35.911982: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:36.520971: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:37.126537: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:37.733072: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:38.266959: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:38.874721: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:39.488041: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:48:40.093075: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:40.698786: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:41.236511: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:41.856812: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:42.449044: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:43.056853: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:43.664966: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:44.203025: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:48:44.835169: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:45.415090: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:46.025596: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:46.636361: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:47.238274: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:47.772924: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:48:48.540528: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.140625
# normalized accuracy = 0.14516128599643707
# Computing REPAIR accuracy for cifar10
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:49:20.188804: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 666060 bytes after encountering the first element of size 666060 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:49:20.792821: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:49:21.936702: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:49:23.149774: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:49:23.757396: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:49:24.365001: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:49:24.902673: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:49:25.537288: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:49:26.116086: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:49:26.728085: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:49:27.333229: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:49:27.940304: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:49:28.473926: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:49:34.539280: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.14443108439445496
# normalized accuracy = 0.14904391765594482
# Computing REPAIR accuracy for eurosat
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:50:06.684314: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:07.828330: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:09.040786: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:09.647922: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:10.256951: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:10.794235: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:50:11.425124: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:12.007246: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:12.617871: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:13.223522: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:13.830513: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:14.364659: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:16.616428: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.1134672611951828
# normalized accuracy = 0.11522477865219116
# Computing REPAIR accuracy for oxford_iiit_pet
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:50:47.303692: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:47.916139: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 666060 bytes after encountering the first element of size 666060 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:50:48.521701: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:49.128325: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:49.665834: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:50.287382: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:50.878100: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:51.486388: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:52.093947: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:52.632419: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:50:53.258902: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:53.845494: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:54.455688: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:55.061354: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:55.669001: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:56.202475: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:50:58.723599: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.07750000059604645
# normalized accuracy = 0.08956301957368851
# Computing REPAIR accuracy for resisc45
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:51:30.029431: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 666060 bytes after encountering the first element of size 666060 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:51:30.634192: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:51:31.777900: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:51:32.399064: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:51:32.989700: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:51:33.597508: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:51:34.205289: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:51:34.744461: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:51:35.376657: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:51:35.956192: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:51:36.567882: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:51:37.172522: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:51:37.779258: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:51:38.312983: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:51:40.766481: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.02701822854578495
# normalized accuracy = 0.029000697657465935
# Computing REPAIR accuracy for cifar100
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:52:07.338762: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 666060 bytes after encountering the first element of size 666060 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:52:07.969744: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:09.162211: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:10.374847: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:11.516581: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:12.129077: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:52:12.734429: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:13.878581: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:14.500712: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:15.091213: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:15.698507: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:16.308878: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:16.845782: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:52:17.471432: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:18.057278: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:18.666906: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:19.273879: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:19.880573: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:20.415615: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:26.478293: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.027944711968302727
# normalized accuracy = 0.03393334895372391
# Computing REPAIR accuracy for cassava
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:52:48.852738: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:49.998918: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:52.425408: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:52.967342: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 666060 bytes after encountering the first element of size 666060 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:52:53.596489: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:54.787810: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:55.393932: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:55.999154: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:56.534278: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:57.141873: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:57.754211: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:52:58.360238: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:58.966637: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:52:59.505661: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:00.125505: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:00.718436: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:01.326784: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:01.934531: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:02.473880: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:53:03.104996: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:03.687480: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:04.298401: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:04.904642: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:05.511537: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:06.047413: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:07.831975: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.2522321343421936
# normalized accuracy = 0.29658791422843933
# Computing REPAIR accuracy for svhn_cropped
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:53:39.125223: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 666060 bytes after encountering the first element of size 666060 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:53:39.730326: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:40.874364: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:42.086939: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:42.695348: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:43.303677: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 12334 bytes after encountering the first element of size 12334 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:43.842742: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 1000054 bytes after encountering the first element of size 1000054 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# 2024-10-11 14:53:44.474891: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 196665 bytes after encountering the first element of size 196665 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:45.055851: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3123 bytes after encountering the first element of size 3123 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:45.667025: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 999050 bytes after encountering the first element of size 999050 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:46.278257: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3080 bytes after encountering the first element of size 3080 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:46.880004: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 67582 bytes after encountering the first element of size 67582 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:53:47.415041: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 3115 bytes after encountering the first element of size 3115 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-10-11 14:54:01.816960: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# accuracy = 0.17268319427967072
# normalized accuracy = 0.18159374594688416

# %%
for ix, dataset in enumerate(datasets):
  print(f"Dataset: {dataset}")
  print(f"\tExpert accuracy = {expert_accs[dataset]}; Merged model accuracy = {merged_accuracies[dataset]}; Merged + REPAIR  accuracy = {repair_accuracies[dataset]}; Merged + TACT accuracy = {tact_accuracies[dataset]}")
  print(f"")
# Out:
# Dataset: colorectal_histology
# 	Expert accuracy = 0.96875; Merged model accuracy = 0.5390625; Merged + REPAIR  accuracy = 0.140625; Merged + TACT accuracy = 0.8697916865348816
#
# Dataset: cifar10
# 	Expert accuracy = 0.9690504670143127; Merged model accuracy = 0.7926682829856873; Merged + REPAIR  accuracy = 0.14443108439445496; Merged + TACT accuracy = 0.9259815812110901
#
# Dataset: eurosat
# 	Expert accuracy = 0.984747052192688; Merged model accuracy = 0.5279017686843872; Merged + REPAIR  accuracy = 0.1134672611951828; Merged + TACT accuracy = 0.9226190447807312
#
# Dataset: oxford_iiit_pet
# 	Expert accuracy = 0.8653125166893005; Merged model accuracy = 0.37031251192092896; Merged + REPAIR  accuracy = 0.07750000059604645; Merged + TACT accuracy = 0.7215625047683716
#
# Dataset: resisc45
# 	Expert accuracy = 0.931640625; Merged model accuracy = 0.3167317807674408; Merged + REPAIR  accuracy = 0.02701822854578495; Merged + TACT accuracy = 0.744140625
#
# Dataset: cifar100
# 	Expert accuracy = 0.8235176205635071; Merged model accuracy = 0.4151642620563507; Merged + REPAIR  accuracy = 0.027944711968302727; Merged + TACT accuracy = 0.6824919581413269
#
# Dataset: cassava
# 	Expert accuracy = 0.8504464030265808; Merged model accuracy = 0.5245535969734192; Merged + REPAIR  accuracy = 0.2522321343421936; Merged + TACT accuracy = 0.7287946343421936
#
# Dataset: svhn_cropped
# 	Expert accuracy = 0.9509313702583313; Merged model accuracy = 0.7521551847457886; Merged + REPAIR  accuracy = 0.17268319427967072; Merged + TACT accuracy = 0.8906635046005249
